# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import os 
import geoviews

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
#city_data_df = pd.read_csv("../WeatherPy_database.csv")

city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")

# %%
# Display sample data
city_data_df.head()
# Out:
#    City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Port Elizabeth      ZA -33.9180   25.5701     67.32        91
# 1        1          Iwanai      JP  42.9744  140.5089     51.01        56
# 2        2       Busselton      AU -33.6500  115.3333     64.15        43
# 3        3   Ayutuxtepeque      SV  13.7456  -89.2064     73.06       100
# 4        4        Freeport      US  40.6576  -73.5832     53.02        87
#
#    Cloudiness  Wind Speed Current Description
# 0           0       11.50           clear sky
# 1           0       17.96           clear sky
# 2          54       13.62       broken clouds
# 3          50        1.01    scattered clouds
# 4         100        6.91     overcast clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.

vacation_min_temp = float(input("What is the minimum temperature you would like for your vacation?  "))
vacation_max_temp = float(input("What is the maximum temperature you would like for your vacation?  "))
# Out:
# What is the minimum temperature you would like for your vacation?  76
# What is the maximum temperature you would like for your vacation?  95

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.

filter_city_data = (city_data_df['Max Temp'] >= vacation_min_temp) & (city_data_df['Max Temp'] <= vacation_max_temp)

preferred_cities_df = city_data_df.loc[filter_city_data]

# Display sample data

preferred_cities_df.head()
# Out:
#     City_ID       City Country      Lat       Lng  Max Temp  Humidity  \
# 6         6   Bengkulu      ID  -3.8004  102.2655     79.84        80
# 9         9      Tabas      IR  33.5959   56.9244     81.59        25
# 17       17  Mahebourg      MU -20.4081   57.7000     80.26        88
# 18       18     Avarua      CK -21.2078 -159.7750     77.05        83
# 20       20   Benguela      AO -12.5763   13.4055     78.33        84
#
#     Cloudiness  Wind Speed Current Description
# 6          100        2.21     overcast clouds
# 9           97        4.18     overcast clouds
# 17          75        3.44       broken clouds
# 18          75        5.75       broken clouds
# 20          96        1.86     overcast clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.

# Count missing values for each column in preferred_cities_df.
preferred_cities_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.

# Display sample data
clean_travel_cities_df = preferred_cities_df.dropna()

clean_travel_cities_df.head()
# Out:
#     City_ID       City Country      Lat       Lng  Max Temp  Humidity  \
# 6         6   Bengkulu      ID  -3.8004  102.2655     79.84        80
# 9         9      Tabas      IR  33.5959   56.9244     81.59        25
# 17       17  Mahebourg      MU -20.4081   57.7000     80.26        88
# 18       18     Avarua      CK -21.2078 -159.7750     77.05        83
# 20       20   Benguela      AO -12.5763   13.4055     78.33        84
#
#     Cloudiness  Wind Speed Current Description
# 6          100        2.21     overcast clouds
# 9           97        4.18     overcast clouds
# 17          75        3.44       broken clouds
# 18          75        5.75       broken clouds
# 20          96        1.86     overcast clouds

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.

hotel_df = clean_travel_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
hotel_df.head()
# Out:
#          City Country  Max Temp Current Description      Lat       Lng
# 6    Bengkulu      ID     79.84     overcast clouds  -3.8004  102.2655
# 9       Tabas      IR     81.59     overcast clouds  33.5959   56.9244
# 17  Mahebourg      MU     80.26       broken clouds -20.4081   57.7000
# 18     Avarua      CK     77.05       broken clouds -21.2078 -159.7750
# 20   Benguela      AO     78.33     overcast clouds -12.5763   13.4055

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".

hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df.head()
# Out:
#          City Country  Max Temp Current Description      Lat       Lng  \
# 6    Bengkulu      ID     79.84     overcast clouds  -3.8004  102.2655
# 9       Tabas      IR     81.59     overcast clouds  33.5959   56.9244
# 17  Mahebourg      MU     80.26       broken clouds -20.4081   57.7000
# 18     Avarua      CK     77.05       broken clouds -21.2078 -159.7750
# 20   Benguela      AO     78.33     overcast clouds -12.5763   13.4055
#
#    Hotel Name
# 6
# 9
# 17
# 18
# 20

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel.

radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame

for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary    
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.    
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionary    
    # name_address = # YOUR CODE HERE
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format.
    
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, 
    # if a hotel isn't found set the hotel name as "No hotel found".
    
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
# Out:
# Starting hotel search
# Bengkulu - nearest hotel: Dena Hotel
# Tabas - nearest hotel: هتل امیر
# Mahebourg - nearest hotel: Grand Bel Air
# Avarua - nearest hotel: Paradise Inn
# Benguela - nearest hotel: Hotel Moibela
# Georgetown - nearest hotel: Page 63 hostel
# Piacabucu - nearest hotel: O Leão
# Wukari - nearest hotel: No hotel found
# Kudat - nearest hotel: Hotel Ria
# Namatanai - nearest hotel: Namatanai Hotel
# Vaini - nearest hotel: Keleti International Resort
# Kavaratti - nearest hotel: No hotel found
# Along - nearest hotel: Hotel Toshi Palace
# Jiwani - nearest hotel: No hotel found
# Cockburn Town - nearest hotel: The Salt Raker Inn
# Bambous Virieux - nearest hotel: No hotel found
# Bambanglipuro - nearest hotel: Puri Ganjuran
# Cozumel - nearest hotel: Hotel Isla Esmeralda
# Umm Kaddadah - nearest hotel: No hotel found
# Le Vauclin - nearest hotel: Hôtel Macabou
# Hoa Binh - nearest hotel: Hải Dương
# Duki - nearest hotel: No hotel found
# San Patricio - nearest hotel: No hotel found
# Iquitos - nearest hotel: Marfil del Amazonas
# Alice Town - nearest hotel: No hotel found
# Atuona - nearest hotel: Pearl Resort
# Labuhan - nearest hotel: No hotel found
# Ugoofaaru - nearest hotel: No hotel found
# Sassandra - nearest hotel: Hotel Le Pollet
# Kapaa - nearest hotel: Pono Kai Resort
# Pangkalanbuun - nearest hotel: Hotel Tiara
# Faanui - nearest hotel: Oa Oa Lodge
# Saint-Philippe - nearest hotel: Le Baril
# Noumea - nearest hotel: Hotel Gondwana
# Yaan - nearest hotel: No hotel found
# Carnarvon - nearest hotel: No hotel found
# Isangel - nearest hotel: Tanna Lodge
# Katherine - nearest hotel: No hotel found
# Wanning - nearest hotel: No hotel found
# Lao Cai - nearest hotel: Bảo Son Hotel
# Gamba - nearest hotel: No hotel found
# Butaritari - nearest hotel: No hotel found
# Lafiagi - nearest hotel: No hotel found
# Kirakira - nearest hotel: No hotel found
# Hithadhoo - nearest hotel: Pebbles Inn
# Honiara - nearest hotel: King Solomon Hotel
# Hilo - nearest hotel: Dolphin Bay Hotel
# Vanimo - nearest hotel: CBC Guesthouse
# Bo Phloi - nearest hotel: 블루사파이어
# Touros - nearest hotel: Pousada Atlântico
# Puerto Escondido - nearest hotel: Hotel Barlovento
# Takaungu - nearest hotel: No hotel found
# Laguna - nearest hotel: Holiday Inn Express & Suites
# Lagos - nearest hotel: No hotel found
# Biak - nearest hotel: No hotel found
# Nelson Bay - nearest hotel: No hotel found
# Padang - nearest hotel: losmen Surya
# Jiangmen - nearest hotel: 如家酒店
# Bridgetown - nearest hotel: Radisson Aquatica Resort
# Omboue - nearest hotel: Hôtel Georges Faustin Aurat
# Paita - nearest hotel: Victor's
# Bandarbeyla - nearest hotel: No hotel found
# Vega De Alatorre - nearest hotel: No hotel found
# Chenzhou - nearest hotel: 明桂园酒店
# Pandan - nearest hotel: No hotel found
# Yeppoon - nearest hotel: Blossom's on Seaspray
# Baran - nearest hotel: Hotel surya
# Kavieng - nearest hotel: Kavieng Hotel
# Aloleng - nearest hotel: No hotel found
# Victoria - nearest hotel: 四季酒店 Four Seasons Hotel
# Bathsheba - nearest hotel: Atlantis Hotel
# Kottagudem - nearest hotel: Hotel welcome
# Ambilobe - nearest hotel: Hôtel National
# Mecca - nearest hotel: Rehab Al Marwa Hotel 1
# Port Keats - nearest hotel: No hotel found
# Voh - nearest hotel: Le Vook
# Kismayo - nearest hotel: Kismayo Hotel
# Koungou - nearest hotel: Hôtel Trévani
# Grand Gaube - nearest hotel: Coco Villa
# Bowen - nearest hotel: Whitsunday Sands Resort
# Batemans Bay - nearest hotel: Esplanade Hotel
# Selma - nearest hotel: Best Western
# Pimentel - nearest hotel: Hospedaje Calle del Sol
# Caucaia - nearest hotel: No hotel found
# Buala - nearest hotel: No hotel found
# Salalah - nearest hotel: Muscat International Hotel
# Dingle - nearest hotel: No hotel found
# Mitsamiouli - nearest hotel: Hotel le Paradis
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Kokopo - nearest hotel: Hotel Kokopo
# Mareeba - nearest hotel: The Gateway Hotel
# Quatre Cocos - nearest hotel: Horisun
# Aswan - nearest hotel: Yaseen hotel
# Kalmunai - nearest hotel: Saji new food
# Cairns - nearest hotel: Cairns Queens Court Accommodation
# Makakilo City - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# Fare - nearest hotel: hôtel Maitai Lapita Village
# Soyo - nearest hotel: Hotel Maria Teres
# Atar - nearest hotel: فندق سكليل
# Porbandar - nearest hotel: Toran Tourist Bungalow
# Kalang - nearest hotel: No hotel found
# Meulaboh - nearest hotel: Hotel Meuligou
# Basco - nearest hotel: Tawsen Hotel
# Tual - nearest hotel: Suita
# Parrita - nearest hotel: Hotel Paraíso Carlisa
# Santa Rosa - nearest hotel: JARS RESORT
# Hirara - nearest hotel: 古謝そば屋
# Yulara - nearest hotel: Outback Pioneer Hotel & Lodge
# Sur - nearest hotel: Sur Hotel
# Ojinaga - nearest hotel: Hotel
# Mount Isa - nearest hotel: Ibis Styles
# Arya - nearest hotel: Gulf Hotel
# Kibala - nearest hotel: No hotel found
# Road Town - nearest hotel: No hotel found
# Kunya - nearest hotel: No hotel found
# Mahibadhoo - nearest hotel: No hotel found
# Saint-Pierre - nearest hotel: Tropic Hotel
# Sulangan - nearest hotel: Marion's Inn
# Morrope - nearest hotel: No hotel found
# Wahiawa - nearest hotel: The Inn At Schofield
# Maceio - nearest hotel: Maceió Hostel e Pousada
# Thinadhoo - nearest hotel: No hotel found
# San Pedro - nearest hotel: Hotel Takara
# Karratha - nearest hotel: Karratha International Hotel
# Kieta - nearest hotel: No hotel found
# Tadine - nearest hotel: No hotel found
# Guhagar - nearest hotel: Prestige Deluxe
# Clarence Town - nearest hotel: Erringhi Hotel
# Ranong - nearest hotel: Rattana Sin Hotel
# Bima - nearest hotel: No hotel found
# Majene - nearest hotel: No hotel found
# Kualakapuas - nearest hotel: Hotel Bayu
# Port Augusta - nearest hotel: Hotel Commonwealth
# Flinders - nearest hotel: No hotel found
# Chake Chake - nearest hotel: Annex Pemba Hotel
# Sai Buri - nearest hotel: No hotel found
# Pasni - nearest hotel: Juddi Hotel
# Akyab - nearest hotel: Yuzana Aung Motel 1
# Osmena - nearest hotel: No hotel found
# Arlit - nearest hotel: No hotel found
# Luganville - nearest hotel: Beachfront Resort
# Hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# Weligama - nearest hotel: Basecamp
# Waingapu - nearest hotel: HOTEL SANDLEWOOD
# Tezu - nearest hotel: No hotel found
# Sechura - nearest hotel: Hospedaje Claritza
# Gladstone - nearest hotel: Gladstone Downtown Central
# Maragogi - nearest hotel: Pousada Mariluz
# Alice Springs - nearest hotel: Aurora Alice Springs
# Alyangula - nearest hotel: No hotel found
# Mont-Dore - nearest hotel: No hotel found
# Tautira - nearest hotel: No hotel found
# Conakry - nearest hotel: Hotel del Fanta (sleazy but rooms for 100k or even less)
# Dabakala - nearest hotel: Hôtel Résidence les villages
# Paka - nearest hotel: Paka Inn
# Talara - nearest hotel: Hospedaje El Aypate
# Sinnamary - nearest hotel: Hôtel du fleuve
# Atambua - nearest hotel: Hotel Matahari
# Port Hedland - nearest hotel: The Esplanade Hotel
# Auki - nearest hotel: No hotel found
# San Fernando - nearest hotel: Pampanga Lodge and Restaurant
# Da Nang - nearest hotel: Thanh Thanh Hotel
# Kanniyakumari - nearest hotel: The Seashore Hotel
# Jizan - nearest hotel: No hotel found
# Manta - nearest hotel: La Gaviota
# Iralaya - nearest hotel: No hotel found
# Lazaro Cardenas - nearest hotel: Hotel Sol del Pacífico
# Eyl - nearest hotel: فندق ايل دابي
# Dzilam Gonzalez - nearest hotel: No hotel found
# Kiunga - nearest hotel: No hotel found
# Kontagora - nearest hotel: No hotel found
# Dawlatabad - nearest hotel: No hotel found
# Olinda - nearest hotel: Fidji Motel
# Blackwater - nearest hotel: No hotel found
# Pochutla - nearest hotel: Posada San Jose
# Bosaso - nearest hotel: Bosaso hotel
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Kerema - nearest hotel: No hotel found
# Sawakin - nearest hotel: Hotel Halfa
# Kulhudhuffushi - nearest hotel: No hotel found
# Avanigadda - nearest hotel: No hotel found
# Barra Patuca - nearest hotel: No hotel found
# Keti Bandar - nearest hotel: No hotel found
# Sibolga - nearest hotel: Hotel Prima Indah
# Alibag - nearest hotel: Chirag executive
# Moree - nearest hotel: No hotel found
# Gizo - nearest hotel: Gizo Hotel
# Freetown - nearest hotel: Formal Leona hotel
# Riohacha - nearest hotel: IMPERIAL
# Ixtapa - nearest hotel: No hotel found
# Pokhara - nearest hotel: Hotel Annapurna View Sarangkot
# Tahoua - nearest hotel: Hotel Bungalow

# %%
# Display sample data
hotel_df.sample(10)
# Out:
#             City Country  Max Temp Current Description      Lat       Lng  \
# 152     Kirakira      SB     84.02    scattered clouds -10.4544  161.9205
# 313         Soyo      AO     78.31     overcast clouds  -6.1349   12.3689
# 538       Talara      PE     78.75          light rain  -4.5772  -81.2719
# 352          Sur      OM     83.26           clear sky  22.5667   59.5289
# 640  Keti Bandar      PK     83.64     overcast clouds  24.1447   67.4497
# 481         Tezu      IN     92.91           clear sky  27.9167   96.1667
# 654         Gizo      SB     84.45          light rain  -8.1030  156.8419
# 464        Arlit      NE     79.50       broken clouds  18.7369    7.3853
# 252   Port Keats      AU     93.40       broken clouds -14.2500  129.5500
# 319       Kalang      PH     85.06     overcast clouds   5.9197  121.3631
#
#               Hotel Name
# 152       No hotel found
# 313    Hotel Maria Teres
# 538  Hospedaje El Aypate
# 352            Sur Hotel
# 640       No hotel found
# 481       No hotel found
# 654           Gizo Hotel
# 464       No hotel found
# 252       No hotel found
# 319       No hotel found

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.loc[hotel_df["Hotel Name"] != 'No hotel found']

# Display sample data
clean_hotel_df.sample(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 156         Honiara      SB     83.82          light rain  -9.4333  159.9500
# 121          Noumea      NC     80.58       broken clouds -22.2763  166.4572
# 117  Saint-Philippe      RE     76.12          few clouds -21.3585   55.7679
# 353         Ojinaga      MX     76.15           clear sky  29.5667 -104.4167
# 400        Karratha      AU     86.61     overcast clouds -20.7377  116.8463
# 466      Luganville      VU     82.74           clear sky -15.5333  167.1667
# 468        Weligama      LK     86.04       moderate rain   5.9667   80.4167
# 29        Namatanai      PG     84.52          light rain  -3.6667  152.4333
# 405         Guhagar      IN     90.95           clear sky  17.4842   73.1929
# 436     Kualakapuas      ID     89.65       broken clouds  -3.0091  114.3876
#
#                        Hotel Name
# 156            King Solomon Hotel
# 121                Hotel Gondwana
# 117                      Le Baril
# 353                         Hotel
# 400  Karratha International Hotel
# 466             Beachfront Resort
# 468                      Basecamp
# 29                Namatanai Hotel
# 405               Prestige Deluxe
# 436                    Hotel Bayu

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
with open('WeatherPy_vacation.csv', 'w', encoding='utf-16') as f:

    # Export the City_Data into a csv
    clean_hotel_df.to_csv(f)

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["City", "Country", "Current Description"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Country,Current Description)

# %%
# Take a screenshot of map and save it to the Vacation_Search folder as WeatherPy_vacation_map.png.
