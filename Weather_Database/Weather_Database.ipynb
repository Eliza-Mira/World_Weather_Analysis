# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries

import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# DELIVERABLE 1-Q3
# Use np.random.uniform function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations

lat_lngs = lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# DELIVERABLE 1-Q4 
# Use the citipy module to get the nearest city for each latitude and longitude combination.

# Create an empty list for holding the cities
cities = [] 

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module.
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list.    
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# DELIVERABLE 1-Q5

# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# CRITICAL - AVOID publishing your API key on GitHub repository!!!!!!!!!

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# DELIVERABLE 1-Q5
# Assemble the OpenWeatherMap's API call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# DELIVERABLE 1-Q6

# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city.
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description.
        
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]  
        country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list.
        city_data.append({"City": city.title(),
                          "Lat": lat,
                          "Lng": lng,
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": clouds,
                          "Wind Speed": wind,
                          "Country": country,
                          "Current Description": weather_description})
    
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 1 | iwanai
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | ayutuxtepeque
# Processing Record 6 of Set 1 | freeport
# Processing Record 7 of Set 1 | mentougou
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | turukhansk
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | tabas
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | sorland
# Processing Record 15 of Set 1 | torbay
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | fortuna
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | richards bay
# Processing Record 23 of Set 1 | benguela
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | bektemir
# Processing Record 26 of Set 1 | novouzensk
# Processing Record 27 of Set 1 | piacabucu
# Processing Record 28 of Set 1 | wukari
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | kudat
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | namatanai
# Processing Record 34 of Set 1 | vila velha
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | mount pleasant
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | kavaratti
# Processing Record 41 of Set 1 | pospelikha
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | moose factory
# Processing Record 49 of Set 1 | salto
# Processing Record 50 of Set 1 | new castle
# Processing Record 1 of Set 2 | norman wells
# Processing Record 2 of Set 2 | mikhaylovka
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | kilmallock
# Processing Record 5 of Set 2 | along
# Processing Record 6 of Set 2 | avera
# Processing Record 7 of Set 2 | camaguey
# Processing Record 8 of Set 2 | astipalaia
# City not found. Skipping...
# Processing Record 9 of Set 2 | paamiut
# Processing Record 10 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | jiwani
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | cockburn town
# Processing Record 16 of Set 2 | caetite
# Processing Record 17 of Set 2 | klaksvik
# Processing Record 18 of Set 2 | mae sai
# Processing Record 19 of Set 2 | muscatine
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | lavrentiya
# Processing Record 22 of Set 2 | lecce
# Processing Record 23 of Set 2 | deputatskiy
# Processing Record 24 of Set 2 | bambanglipuro
# Processing Record 25 of Set 2 | miguel alves
# Processing Record 26 of Set 2 | cooma
# Processing Record 27 of Set 2 | hwange
# Processing Record 28 of Set 2 | cidreira
# Processing Record 29 of Set 2 | cozumel
# Processing Record 30 of Set 2 | umm kaddadah
# Processing Record 31 of Set 2 | huescar
# Processing Record 32 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 33 of Set 2 | kozhva
# Processing Record 34 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 35 of Set 2 | tuatapere
# Processing Record 36 of Set 2 | le vauclin
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | kansanshi
# Processing Record 39 of Set 2 | hoa binh
# Processing Record 40 of Set 2 | duki
# Processing Record 41 of Set 2 | dingli
# Processing Record 42 of Set 2 | san patricio
# Processing Record 43 of Set 2 | iquitos
# Processing Record 44 of Set 2 | fulitun
# City not found. Skipping...
# Processing Record 45 of Set 2 | senno
# Processing Record 46 of Set 2 | richmond
# Processing Record 47 of Set 2 | alice town
# Processing Record 48 of Set 2 | chumikan
# Processing Record 49 of Set 2 | ayr
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | pangody
# Processing Record 2 of Set 3 | antofagasta
# Processing Record 3 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 3 | cherskiy
# Processing Record 5 of Set 3 | issoire
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 3 | geraldton
# Processing Record 9 of Set 3 | pangnirtung
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | labuhan
# Processing Record 12 of Set 3 | tazovskiy
# Processing Record 13 of Set 3 | arman
# Processing Record 14 of Set 3 | durango
# Processing Record 15 of Set 3 | tambul
# City not found. Skipping...
# Processing Record 16 of Set 3 | ugoofaaru
# Processing Record 17 of Set 3 | angra
# City not found. Skipping...
# Processing Record 18 of Set 3 | plettenberg bay
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | guerrero negro
# Processing Record 21 of Set 3 | haldia
# Processing Record 22 of Set 3 | sassandra
# Processing Record 23 of Set 3 | vestmannaeyjar
# Processing Record 24 of Set 3 | alihe
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | vila franca do campo
# Processing Record 27 of Set 3 | pangkalanbuun
# Processing Record 28 of Set 3 | talnakh
# Processing Record 29 of Set 3 | asau
# Processing Record 30 of Set 3 | faanui
# Processing Record 31 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 32 of Set 3 | saint-philippe
# Processing Record 33 of Set 3 | ladario
# Processing Record 34 of Set 3 | kenai
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | noumea
# Processing Record 37 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 38 of Set 3 | yangliuqing
# Processing Record 39 of Set 3 | constitucion
# Processing Record 40 of Set 3 | ketchikan
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | yaan
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | higuey
# City not found. Skipping...
# Processing Record 45 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 3 | uddevalla
# Processing Record 47 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 3 | airai
# Processing Record 49 of Set 3 | eseka
# Processing Record 50 of Set 3 | isangel
# Processing Record 1 of Set 4 | katherine
# Processing Record 2 of Set 4 | wanning
# Processing Record 3 of Set 4 | okulovka
# Processing Record 4 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 4 | lao cai
# Processing Record 6 of Set 4 | gamba
# Processing Record 7 of Set 4 | cape town
# Processing Record 8 of Set 4 | iqaluit
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | kaberamaido
# Processing Record 11 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 4 | port lincoln
# Processing Record 13 of Set 4 | yellowknife
# Processing Record 14 of Set 4 | hearst
# Processing Record 15 of Set 4 | byron bay
# Processing Record 16 of Set 4 | manzhouli
# Processing Record 17 of Set 4 | balkhash
# Processing Record 18 of Set 4 | hualmay
# Processing Record 19 of Set 4 | lasa
# Processing Record 20 of Set 4 | jamestown
# Processing Record 21 of Set 4 | coaldale
# Processing Record 22 of Set 4 | lafiagi
# Processing Record 23 of Set 4 | kirakira
# Processing Record 24 of Set 4 | nuuk
# Processing Record 25 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 26 of Set 4 | bakchar
# Processing Record 27 of Set 4 | hithadhoo
# Processing Record 28 of Set 4 | honiara
# Processing Record 29 of Set 4 | hilo
# Processing Record 30 of Set 4 | new norfolk
# Processing Record 31 of Set 4 | vanimo
# Processing Record 32 of Set 4 | sitka
# Processing Record 33 of Set 4 | bo phloi
# Processing Record 34 of Set 4 | ozernovskiy
# Processing Record 35 of Set 4 | touros
# Processing Record 36 of Set 4 | arraial do cabo
# Processing Record 37 of Set 4 | albi
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | gravdal
# Processing Record 40 of Set 4 | puerto escondido
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | granadilla de abona
# Processing Record 43 of Set 4 | caravelas
# Processing Record 44 of Set 4 | castro
# Processing Record 45 of Set 4 | takaungu
# Processing Record 46 of Set 4 | nikolskoye
# Processing Record 47 of Set 4 | camabatela
# Processing Record 48 of Set 4 | bomet
# Processing Record 49 of Set 4 | magalia
# Processing Record 50 of Set 4 | shihezi
# Processing Record 1 of Set 5 | nola
# Processing Record 2 of Set 5 | kill
# Processing Record 3 of Set 5 | erenhot
# Processing Record 4 of Set 5 | ilulissat
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | inuvik
# Processing Record 7 of Set 5 | mehamn
# Processing Record 8 of Set 5 | hami
# Processing Record 9 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 5 | uniao
# Processing Record 11 of Set 5 | laguna
# Processing Record 12 of Set 5 | port hueneme
# Processing Record 13 of Set 5 | dikson
# Processing Record 14 of Set 5 | santa clara
# Processing Record 15 of Set 5 | lagos
# Processing Record 16 of Set 5 | chernyshevsk
# Processing Record 17 of Set 5 | te anau
# Processing Record 18 of Set 5 | ribas do rio pardo
# Processing Record 19 of Set 5 | ishigaki
# Processing Record 20 of Set 5 | mar del plata
# Processing Record 21 of Set 5 | bad hall
# Processing Record 22 of Set 5 | otavi
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | biak
# Processing Record 25 of Set 5 | barao de melgaco
# Processing Record 26 of Set 5 | brae
# Processing Record 27 of Set 5 | sao filipe
# Processing Record 28 of Set 5 | lazo
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | nelson bay
# Processing Record 31 of Set 5 | lenger
# Processing Record 32 of Set 5 | mayo
# Processing Record 33 of Set 5 | kahului
# Processing Record 34 of Set 5 | padang
# Processing Record 35 of Set 5 | jiangmen
# Processing Record 36 of Set 5 | nadym
# Processing Record 37 of Set 5 | bridgetown
# Processing Record 38 of Set 5 | kerman
# Processing Record 39 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 5 | lompoc
# Processing Record 41 of Set 5 | atyrau
# Processing Record 42 of Set 5 | omboue
# Processing Record 43 of Set 5 | lagoa
# Processing Record 44 of Set 5 | paita
# Processing Record 45 of Set 5 | botngard
# Processing Record 46 of Set 5 | bandarbeyla
# Processing Record 47 of Set 5 | leningradskiy
# Processing Record 48 of Set 5 | vega de alatorre
# Processing Record 49 of Set 5 | chenzhou
# Processing Record 50 of Set 5 | beloha
# Processing Record 1 of Set 6 | pandan
# Processing Record 2 of Set 6 | sovetskiy
# Processing Record 3 of Set 6 | yeppoon
# Processing Record 4 of Set 6 | east saint louis
# Processing Record 5 of Set 6 | baran
# Processing Record 6 of Set 6 | rogers
# Processing Record 7 of Set 6 | hollola
# Processing Record 8 of Set 6 | yuryevets
# Processing Record 9 of Set 6 | kavieng
# Processing Record 10 of Set 6 | nanortalik
# Processing Record 11 of Set 6 | yatou
# Processing Record 12 of Set 6 | marienburg
# Processing Record 13 of Set 6 | port hardy
# Processing Record 14 of Set 6 | prince rupert
# Processing Record 15 of Set 6 | luderitz
# Processing Record 16 of Set 6 | naryan-mar
# Processing Record 17 of Set 6 | aloleng
# Processing Record 18 of Set 6 | victoria
# Processing Record 19 of Set 6 | bathsheba
# Processing Record 20 of Set 6 | ust-nera
# Processing Record 21 of Set 6 | kottagudem
# Processing Record 22 of Set 6 | ambilobe
# Processing Record 23 of Set 6 | shingu
# Processing Record 24 of Set 6 | westport
# Processing Record 25 of Set 6 | mecca
# Processing Record 26 of Set 6 | port keats
# Processing Record 27 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 6 | andenes
# Processing Record 29 of Set 6 | praia da vitoria
# Processing Record 30 of Set 6 | atasu
# Processing Record 31 of Set 6 | kaeo
# Processing Record 32 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 6 | voh
# Processing Record 34 of Set 6 | kismayo
# Processing Record 35 of Set 6 | noshiro
# Processing Record 36 of Set 6 | koungou
# Processing Record 37 of Set 6 | grand gaube
# Processing Record 38 of Set 6 | durban
# Processing Record 39 of Set 6 | sepatan
# Processing Record 40 of Set 6 | berdyuzhye
# City not found. Skipping...
# Processing Record 41 of Set 6 | berlevag
# Processing Record 42 of Set 6 | bowen
# Processing Record 43 of Set 6 | batemans bay
# Processing Record 44 of Set 6 | west wendover
# Processing Record 45 of Set 6 | sistranda
# Processing Record 46 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 6 | escanaba
# Processing Record 48 of Set 6 | kawambwa
# Processing Record 49 of Set 6 | saint anthony
# Processing Record 50 of Set 6 | gornopravdinsk
# Processing Record 1 of Set 7 | lebu
# Processing Record 2 of Set 7 | selma
# Processing Record 3 of Set 7 | portland
# Processing Record 4 of Set 7 | pimentel
# Processing Record 5 of Set 7 | ordzhonikidze
# Processing Record 6 of Set 7 | kruisfontein
# Processing Record 7 of Set 7 | cayenne
# Processing Record 8 of Set 7 | pimenta bueno
# Processing Record 9 of Set 7 | grandola
# Processing Record 10 of Set 7 | bonnyville
# Processing Record 11 of Set 7 | caucaia
# Processing Record 12 of Set 7 | buala
# Processing Record 13 of Set 7 | salalah
# Processing Record 14 of Set 7 | dingle
# Processing Record 15 of Set 7 | comodoro rivadavia
# Processing Record 16 of Set 7 | mitsamiouli
# Processing Record 17 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 18 of Set 7 | sochi
# Processing Record 19 of Set 7 | lorengau
# Processing Record 20 of Set 7 | golub-dobrzyn
# Processing Record 21 of Set 7 | kokopo
# Processing Record 22 of Set 7 | campo gobierno
# Processing Record 23 of Set 7 | pacific grove
# Processing Record 24 of Set 7 | clyde river
# Processing Record 25 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 7 | mareeba
# Processing Record 28 of Set 7 | quatre cocos
# Processing Record 29 of Set 7 | ust-ishim
# Processing Record 30 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 7 | abha
# Processing Record 32 of Set 7 | carauari
# Processing Record 33 of Set 7 | lewiston
# Processing Record 34 of Set 7 | port macquarie
# Processing Record 35 of Set 7 | jalu
# Processing Record 36 of Set 7 | aswan
# Processing Record 37 of Set 7 | fairbanks
# Processing Record 38 of Set 7 | benghazi
# Processing Record 39 of Set 7 | sidi ali
# Processing Record 40 of Set 7 | kalmunai
# Processing Record 41 of Set 7 | cairns
# Processing Record 42 of Set 7 | coihaique
# Processing Record 43 of Set 7 | makakilo city
# Processing Record 44 of Set 7 | fare
# Processing Record 45 of Set 7 | soyo
# Processing Record 46 of Set 7 | rio gallegos
# Processing Record 47 of Set 7 | atar
# Processing Record 48 of Set 7 | porbandar
# Processing Record 49 of Set 7 | choix
# Processing Record 50 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 1 of Set 8 | vao
# Processing Record 2 of Set 8 | kalang
# Processing Record 3 of Set 8 | meulaboh
# Processing Record 4 of Set 8 | gualaco
# Processing Record 5 of Set 8 | lervik
# Processing Record 6 of Set 8 | lerwick
# Processing Record 7 of Set 8 | atikokan
# Processing Record 8 of Set 8 | hammerfest
# Processing Record 9 of Set 8 | rawson
# Processing Record 10 of Set 8 | enshi
# Processing Record 11 of Set 8 | ostersund
# Processing Record 12 of Set 8 | matinhos
# Processing Record 13 of Set 8 | sisimiut
# Processing Record 14 of Set 8 | muros
# Processing Record 15 of Set 8 | varhaug
# Processing Record 16 of Set 8 | beyneu
# Processing Record 17 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 8 | rivadavia
# Processing Record 19 of Set 8 | longyearbyen
# Processing Record 20 of Set 8 | basco
# Processing Record 21 of Set 8 | baie-comeau
# Processing Record 22 of Set 8 | saint george
# Processing Record 23 of Set 8 | linares
# Processing Record 24 of Set 8 | tayshet
# Processing Record 25 of Set 8 | tual
# Processing Record 26 of Set 8 | parrita
# Processing Record 27 of Set 8 | santa rosa
# Processing Record 28 of Set 8 | basoko
# Processing Record 29 of Set 8 | orsha
# Processing Record 30 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 31 of Set 8 | tiksi
# Processing Record 32 of Set 8 | inverness
# Processing Record 33 of Set 8 | hirara
# Processing Record 34 of Set 8 | yulara
# Processing Record 35 of Set 8 | ekhabi
# Processing Record 36 of Set 8 | pevek
# Processing Record 37 of Set 8 | sur
# Processing Record 38 of Set 8 | ojinaga
# Processing Record 39 of Set 8 | elmira
# Processing Record 40 of Set 8 | enid
# Processing Record 41 of Set 8 | hornepayne
# Processing Record 42 of Set 8 | mount isa
# Processing Record 43 of Set 8 | santarem
# Processing Record 44 of Set 8 | perth
# Processing Record 45 of Set 8 | la palma
# Processing Record 46 of Set 8 | bolu
# Processing Record 47 of Set 8 | rabo de peixe
# Processing Record 48 of Set 8 | ostrovnoy
# Processing Record 49 of Set 8 | mwanza
# Processing Record 50 of Set 8 | nepalganj
# City not found. Skipping...
# Processing Record 1 of Set 9 | zhigansk
# Processing Record 2 of Set 9 | arya
# Processing Record 3 of Set 9 | boende
# Processing Record 4 of Set 9 | ancud
# Processing Record 5 of Set 9 | kibala
# Processing Record 6 of Set 9 | bilibino
# Processing Record 7 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 9 | codrington
# Processing Record 9 of Set 9 | zhangjiakou
# Processing Record 10 of Set 9 | berdigestyakh
# Processing Record 11 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 9 | road town
# Processing Record 13 of Set 9 | teeli
# Processing Record 14 of Set 9 | rocha
# Processing Record 15 of Set 9 | quelimane
# Processing Record 16 of Set 9 | price
# Processing Record 17 of Set 9 | kunya
# Processing Record 18 of Set 9 | mahibadhoo
# Processing Record 19 of Set 9 | henties bay
# Processing Record 20 of Set 9 | beringovskiy
# Processing Record 21 of Set 9 | cherat
# Processing Record 22 of Set 9 | moron
# Processing Record 23 of Set 9 | saint-pierre
# Processing Record 24 of Set 9 | camana
# Processing Record 25 of Set 9 | sulangan
# Processing Record 26 of Set 9 | morrope
# Processing Record 27 of Set 9 | myitkyina
# Processing Record 28 of Set 9 | tooele
# Processing Record 29 of Set 9 | kachug
# Processing Record 30 of Set 9 | wahiawa
# Processing Record 31 of Set 9 | realeza
# Processing Record 32 of Set 9 | maceio
# Processing Record 33 of Set 9 | amazar
# Processing Record 34 of Set 9 | sapao
# City not found. Skipping...
# Processing Record 35 of Set 9 | filadelfia
# Processing Record 36 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 9 | thinadhoo
# Processing Record 38 of Set 9 | san pedro
# Processing Record 39 of Set 9 | senanga
# Processing Record 40 of Set 9 | karratha
# Processing Record 41 of Set 9 | shelburne
# Processing Record 42 of Set 9 | kieta
# Processing Record 43 of Set 9 | arkhipo-osipovka
# Processing Record 44 of Set 9 | tadine
# Processing Record 45 of Set 9 | guhagar
# Processing Record 46 of Set 9 | ilhabela
# Processing Record 47 of Set 9 | clarence town
# Processing Record 48 of Set 9 | albania
# Processing Record 49 of Set 9 | andra
# Processing Record 50 of Set 9 | naron
# Processing Record 1 of Set 10 | pankovka
# Processing Record 2 of Set 10 | ranong
# Processing Record 3 of Set 10 | bima
# Processing Record 4 of Set 10 | matsuura
# Processing Record 5 of Set 10 | nome
# Processing Record 6 of Set 10 | meadow lake
# Processing Record 7 of Set 10 | dalvik
# Processing Record 8 of Set 10 | davydivka
# Processing Record 9 of Set 10 | pyshma
# Processing Record 10 of Set 10 | kosh-agach
# Processing Record 11 of Set 10 | dalaba
# Processing Record 12 of Set 10 | redwater
# Processing Record 13 of Set 10 | nam som
# Processing Record 14 of Set 10 | yerbogachen
# Processing Record 15 of Set 10 | majene
# Processing Record 16 of Set 10 | esperance
# Processing Record 17 of Set 10 | batangafo
# Processing Record 18 of Set 10 | kostomuksha
# Processing Record 19 of Set 10 | olafsvik
# Processing Record 20 of Set 10 | nyurba
# Processing Record 21 of Set 10 | albanel
# Processing Record 22 of Set 10 | uzhur
# Processing Record 23 of Set 10 | catamarca
# Processing Record 24 of Set 10 | salta
# Processing Record 25 of Set 10 | varzea da palma
# Processing Record 26 of Set 10 | kualakapuas
# Processing Record 27 of Set 10 | kabinda
# Processing Record 28 of Set 10 | porto santo
# Processing Record 29 of Set 10 | port augusta
# Processing Record 30 of Set 10 | girne
# Processing Record 31 of Set 10 | finnsnes
# Processing Record 32 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 10 | flinders
# Processing Record 35 of Set 10 | isiro
# Processing Record 36 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 10 | colares
# Processing Record 38 of Set 10 | san ramon
# Processing Record 39 of Set 10 | jijiga
# Processing Record 40 of Set 10 | clearlake
# Processing Record 41 of Set 10 | skjold
# Processing Record 42 of Set 10 | beidao
# Processing Record 43 of Set 10 | san cristobal
# Processing Record 44 of Set 10 | chake chake
# Processing Record 45 of Set 10 | egvekinot
# Processing Record 46 of Set 10 | sai buri
# Processing Record 47 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 48 of Set 10 | yabelo
# Processing Record 49 of Set 10 | botwood
# Processing Record 50 of Set 10 | saint paul
# Processing Record 1 of Set 11 | chipinge
# Processing Record 2 of Set 11 | damara
# Processing Record 3 of Set 11 | pasni
# Processing Record 4 of Set 11 | bud
# Processing Record 5 of Set 11 | akyab
# Processing Record 6 of Set 11 | osmena
# Processing Record 7 of Set 11 | natal
# Processing Record 8 of Set 11 | arlit
# Processing Record 9 of Set 11 | henstedt-ulzburg
# Processing Record 10 of Set 11 | luganville
# Processing Record 11 of Set 11 | hambantota
# Processing Record 12 of Set 11 | weligama
# Processing Record 13 of Set 11 | gillette
# Processing Record 14 of Set 11 | narsaq
# Processing Record 15 of Set 11 | hasaki
# Processing Record 16 of Set 11 | mago
# Processing Record 17 of Set 11 | montague
# Processing Record 18 of Set 11 | gisborne
# Processing Record 19 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 11 | tuysarkan
# City not found. Skipping...
# Processing Record 21 of Set 11 | waingapu
# Processing Record 22 of Set 11 | kysyl-syr
# Processing Record 23 of Set 11 | necochea
# Processing Record 24 of Set 11 | chongwe
# Processing Record 25 of Set 11 | mezhdurechensk
# Processing Record 26 of Set 11 | springdale
# Processing Record 27 of Set 11 | tezu
# Processing Record 28 of Set 11 | batagay-alyta
# Processing Record 29 of Set 11 | san lorenzo
# Processing Record 30 of Set 11 | sechura
# Processing Record 31 of Set 11 | watertown
# Processing Record 32 of Set 11 | gladstone
# Processing Record 33 of Set 11 | san vicente
# Processing Record 34 of Set 11 | puerto narino
# Processing Record 35 of Set 11 | kashi
# Processing Record 36 of Set 11 | siyabuswa
# Processing Record 37 of Set 11 | jimma
# Processing Record 38 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 11 | casper
# Processing Record 40 of Set 11 | oskemen
# Processing Record 41 of Set 11 | maragogi
# Processing Record 42 of Set 11 | los llanos de aridane
# Processing Record 43 of Set 11 | columbus
# Processing Record 44 of Set 11 | fort nelson
# Processing Record 45 of Set 11 | guamuchil
# Processing Record 46 of Set 11 | marystown
# Processing Record 47 of Set 11 | el alto
# Processing Record 48 of Set 11 | vanavara
# Processing Record 49 of Set 11 | powell river
# Processing Record 50 of Set 11 | sergeyevka
# Processing Record 1 of Set 12 | saldanha
# Processing Record 2 of Set 12 | shengjin
# Processing Record 3 of Set 12 | glubczyce
# Processing Record 4 of Set 12 | thurso
# Processing Record 5 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 12 | turtas
# Processing Record 7 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 8 of Set 12 | vostok
# Processing Record 9 of Set 12 | buzmeyin
# Processing Record 10 of Set 12 | ocampo
# Processing Record 11 of Set 12 | alice springs
# Processing Record 12 of Set 12 | havoysund
# Processing Record 13 of Set 12 | alyangula
# Processing Record 14 of Set 12 | drumheller
# Processing Record 15 of Set 12 | deer lake
# Processing Record 16 of Set 12 | korla
# Processing Record 17 of Set 12 | mont-dore
# Processing Record 18 of Set 12 | gat
# Processing Record 19 of Set 12 | yaypan
# Processing Record 20 of Set 12 | anadyr
# Processing Record 21 of Set 12 | tautira
# Processing Record 22 of Set 12 | ponta do sol
# Processing Record 23 of Set 12 | zhezkazgan
# Processing Record 24 of Set 12 | tabulbah
# City not found. Skipping...
# Processing Record 25 of Set 12 | kropotkin
# Processing Record 26 of Set 12 | conakry
# Processing Record 27 of Set 12 | valkeala
# Processing Record 28 of Set 12 | krasnorechenskiy
# Processing Record 29 of Set 12 | sao joao da barra
# Processing Record 30 of Set 12 | terrace bay
# Processing Record 31 of Set 12 | dabakala
# Processing Record 32 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 12 | baoro
# Processing Record 34 of Set 12 | bulungu
# Processing Record 35 of Set 12 | paka
# Processing Record 36 of Set 12 | new london
# Processing Record 37 of Set 12 | shimoda
# Processing Record 38 of Set 12 | tolmachevo
# Processing Record 39 of Set 12 | talara
# Processing Record 40 of Set 12 | baykit
# Processing Record 41 of Set 12 | dauphin
# Processing Record 42 of Set 12 | buraydah
# Processing Record 43 of Set 12 | vardo
# Processing Record 44 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 45 of Set 12 | sinnamary
# Processing Record 46 of Set 12 | bira
# Processing Record 47 of Set 12 | thoen
# Processing Record 48 of Set 12 | nueve de julio
# Processing Record 49 of Set 12 | atambua
# Processing Record 50 of Set 12 | bonavista
# Processing Record 1 of Set 13 | lyuban
# Processing Record 2 of Set 13 | port hedland
# Processing Record 3 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 4 of Set 13 | mustasaari
# Processing Record 5 of Set 13 | jutai
# Processing Record 6 of Set 13 | riviere-au-renard
# Processing Record 7 of Set 13 | fort-shevchenko
# Processing Record 8 of Set 13 | estevan
# Processing Record 9 of Set 13 | cochabamba
# Processing Record 10 of Set 13 | auki
# Processing Record 11 of Set 13 | san fernando
# Processing Record 12 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 13 | da nang
# Processing Record 14 of Set 13 | balvi
# Processing Record 15 of Set 13 | coquimbo
# Processing Record 16 of Set 13 | krasnoshchekovo
# Processing Record 17 of Set 13 | mandan
# Processing Record 18 of Set 13 | awbari
# Processing Record 19 of Set 13 | visby
# Processing Record 20 of Set 13 | skibbereen
# Processing Record 21 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 22 of Set 13 | kanniyakumari
# Processing Record 23 of Set 13 | pucallpa
# Processing Record 24 of Set 13 | jizan
# Processing Record 25 of Set 13 | batagay
# Processing Record 26 of Set 13 | chara
# Processing Record 27 of Set 13 | general salgado
# Processing Record 28 of Set 13 | manta
# Processing Record 29 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 13 | danville
# Processing Record 31 of Set 13 | shache
# Processing Record 32 of Set 13 | iralaya
# Processing Record 33 of Set 13 | buin
# Processing Record 34 of Set 13 | lazaro cardenas
# Processing Record 35 of Set 13 | nagato
# Processing Record 36 of Set 13 | wilmington
# Processing Record 37 of Set 13 | tilichiki
# Processing Record 38 of Set 13 | severnoye
# Processing Record 39 of Set 13 | eyl
# Processing Record 40 of Set 13 | pavlodar
# Processing Record 41 of Set 13 | luau
# Processing Record 42 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 13 | rio grande
# Processing Record 44 of Set 13 | gayny
# Processing Record 45 of Set 13 | dzilam gonzalez
# Processing Record 46 of Set 13 | asyut
# Processing Record 47 of Set 13 | boyuibe
# Processing Record 48 of Set 13 | toulepleu
# City not found. Skipping...
# Processing Record 49 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 13 | kiunga
# Processing Record 1 of Set 14 | mantua
# Processing Record 2 of Set 14 | constantine
# Processing Record 3 of Set 14 | kontagora
# Processing Record 4 of Set 14 | tucurui
# Processing Record 5 of Set 14 | northam
# Processing Record 6 of Set 14 | salina
# Processing Record 7 of Set 14 | korem
# Processing Record 8 of Set 14 | dawlatabad
# Processing Record 9 of Set 14 | cuamba
# Processing Record 10 of Set 14 | namie
# Processing Record 11 of Set 14 | verkhnetulomskiy
# Processing Record 12 of Set 14 | antipovka
# Processing Record 13 of Set 14 | praia
# Processing Record 14 of Set 14 | olinda
# Processing Record 15 of Set 14 | huntsville
# Processing Record 16 of Set 14 | ravar
# Processing Record 17 of Set 14 | coxim
# Processing Record 18 of Set 14 | mangalia
# Processing Record 19 of Set 14 | ullapool
# Processing Record 20 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 14 | blackwater
# Processing Record 22 of Set 14 | goderich
# Processing Record 23 of Set 14 | pochutla
# Processing Record 24 of Set 14 | huilong
# Processing Record 25 of Set 14 | weihai
# Processing Record 26 of Set 14 | lastoursville
# Processing Record 27 of Set 14 | north bend
# Processing Record 28 of Set 14 | de aar
# Processing Record 29 of Set 14 | bosaso
# Processing Record 30 of Set 14 | port blair
# Processing Record 31 of Set 14 | zharkent
# Processing Record 32 of Set 14 | kerema
# Processing Record 33 of Set 14 | la ronge
# Processing Record 34 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 14 | hamada
# Processing Record 36 of Set 14 | lata
# Processing Record 37 of Set 14 | aracatuba
# Processing Record 38 of Set 14 | sawakin
# Processing Record 39 of Set 14 | kulhudhuffushi
# Processing Record 40 of Set 14 | nuziders
# Processing Record 41 of Set 14 | kango
# Processing Record 42 of Set 14 | avanigadda
# Processing Record 43 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 14 | krasnyy chikoy
# Processing Record 45 of Set 14 | truro
# Processing Record 46 of Set 14 | gazanjyk
# Processing Record 47 of Set 14 | barroualie
# City not found. Skipping...
# Processing Record 48 of Set 14 | barra patuca
# Processing Record 49 of Set 14 | anzio
# Processing Record 50 of Set 14 | hofn
# Processing Record 1 of Set 15 | chico
# Processing Record 2 of Set 15 | sarkand
# Processing Record 3 of Set 15 | keti bandar
# Processing Record 4 of Set 15 | sibolga
# Processing Record 5 of Set 15 | alibag
# Processing Record 6 of Set 15 | curuguaty
# Processing Record 7 of Set 15 | valparaiso
# Processing Record 8 of Set 15 | halifax
# Processing Record 9 of Set 15 | moree
# Processing Record 10 of Set 15 | canals
# Processing Record 11 of Set 15 | yarmouth
# Processing Record 12 of Set 15 | gobabis
# Processing Record 13 of Set 15 | mnogovershinnyy
# Processing Record 14 of Set 15 | burica
# City not found. Skipping...
# Processing Record 15 of Set 15 | shuangyang
# Processing Record 16 of Set 15 | broome
# Processing Record 17 of Set 15 | kholodnyy
# Processing Record 18 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 19 of Set 15 | gizo
# Processing Record 20 of Set 15 | solvychegodsk
# Processing Record 21 of Set 15 | komsomolskiy
# Processing Record 22 of Set 15 | ripoll
# Processing Record 23 of Set 15 | marsh harbour
# Processing Record 24 of Set 15 | san joaquin
# Processing Record 25 of Set 15 | freetown
# Processing Record 26 of Set 15 | sion
# Processing Record 27 of Set 15 | hanzhong
# Processing Record 28 of Set 15 | porosozero
# Processing Record 29 of Set 15 | teya
# Processing Record 30 of Set 15 | luena
# Processing Record 31 of Set 15 | riohacha
# Processing Record 32 of Set 15 | kushmurun
# Processing Record 33 of Set 15 | maykain
# City not found. Skipping...
# Processing Record 34 of Set 15 | tahlequah
# Processing Record 35 of Set 15 | ixtapa
# Processing Record 36 of Set 15 | firozabad
# Processing Record 37 of Set 15 | harbour breton
# Processing Record 38 of Set 15 | unye
# City not found. Skipping...
# Processing Record 39 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 40 of Set 15 | rincon
# Processing Record 41 of Set 15 | great yarmouth
# Processing Record 42 of Set 15 | fukue
# Processing Record 43 of Set 15 | opuwo
# Processing Record 44 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 45 of Set 15 | lyngseidet
# Processing Record 46 of Set 15 | tsentralnyy
# City not found. Skipping...
# Processing Record 47 of Set 15 | katsuura
# Processing Record 48 of Set 15 | montepuez
# Processing Record 49 of Set 15 | seoul
# Processing Record 50 of Set 15 | yoichi
# Processing Record 1 of Set 16 | brits
# Processing Record 2 of Set 16 | pokhara
# Processing Record 3 of Set 16 | tiznit
# Processing Record 4 of Set 16 | whitefish
# Processing Record 5 of Set 16 | turayf
# Processing Record 6 of Set 16 | temiscaming
# Processing Record 7 of Set 16 | tahoua
# Processing Record 8 of Set 16 | seka
# Processing Record 9 of Set 16 | shimanovsk
# Processing Record 10 of Set 16 | cabedelo
# Processing Record 11 of Set 16 | aasiaat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have.

len(city_data)
# Out:
# 692

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# DELIVERABLE 1-Q7

# Use the city_data list to create a new pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data.

city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth -33.9180   25.5701     67.32        91           0
# 1          Iwanai  42.9744  140.5089     51.01        56           0
# 2       Busselton -33.6500  115.3333     64.15        43          54
# 3   Ayutuxtepeque  13.7456  -89.2064     73.06       100          50
# 4        Freeport  40.6576  -73.5832     53.02        87         100
# 5       Mentougou  39.9392  116.0917     61.74        31         100
# 6        Bengkulu  -3.8004  102.2655     79.84        80         100
# 7      Turukhansk  65.8167   87.9833     26.62        86          88
# 8         Qaanaaq  77.4840  -69.3632     -9.29        79           8
# 9           Tabas  33.5959   56.9244     81.59        25          97
#
#    Wind Speed Country Current Description
# 0       11.50      ZA           clear sky
# 1       17.96      JP           clear sky
# 2       13.62      AU       broken clouds
# 3        1.01      SV    scattered clouds
# 4        6.91      US     overcast clouds
# 5        4.09      CN     overcast clouds
# 6        2.21      ID     overcast clouds
# 7        8.03      RU     overcast clouds
# 8        8.05      GL           clear sky
# 9        4.18      IR     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function.

city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

list_citydata_columns_rearranged = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order.

citydata_columns_rearranged_df = city_data_df[list_citydata_columns_rearranged]

# Display sample data.
citydata_columns_rearranged_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth      ZA -33.9180   25.5701     67.32        91           0
# 1          Iwanai      JP  42.9744  140.5089     51.01        56           0
# 2       Busselton      AU -33.6500  115.3333     64.15        43          54
# 3   Ayutuxtepeque      SV  13.7456  -89.2064     73.06       100          50
# 4        Freeport      US  40.6576  -73.5832     53.02        87         100
#
#    Wind Speed Current Description
# 0       11.50           clear sky
# 1       17.96           clear sky
# 2       13.62       broken clouds
# 3        1.01    scattered clouds
# 4        6.91     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function.

citydata_columns_rearranged_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# DELIVERABLE 1-Q8

# Set the output file name.

output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file.

citydata_columns_rearranged_df.to_csv(output_data_file, index_label="City_ID")
